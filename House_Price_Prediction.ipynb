# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\akash\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\akash\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv("1553768847-housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300
# 4         565         259         3.8462        NEAR BAY              342200

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income ocean_proximity  \
# 20635         845         330         1.5603          INLAND
# 20636         356         114         2.5568          INLAND
# 20637        1007         433         1.7000          INLAND
# 20638         741         349         1.8672          INLAND
# 20639        1387         530         2.3886          INLAND
#
#        median_house_value
# 20635               78100
# 20636               77100
# 20637               92300
# 20638               84700
# ...

# %% [markdown]
# # Data Analysis

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity', 'median_house_value'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'ocean_proximity',
#  'median_house_value']

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# median_house_value      0
# dtype: int64

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# ocean_proximity        object
# median_house_value      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
df['total_bedrooms'] = df['total_bedrooms'].fillna(df['total_bedrooms'].mean())

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# ocean_proximity       0
# median_house_value    0
# dtype: int64

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# longitude
# -118.31    162
# -118.30    160
# -118.29    148
# -118.27    144
# -118.32    142
#           ...
# -123.54      1
# -115.94      1
# -115.99      1
# -116.81      1
# -123.71      1
# Name: count, Length: 844, dtype: int64
#
#
# latitude
# 34.06    244
# 34.05    236
# 34.08    234
# 34.07    231
# 34.04    221
#         ...
# 41.01      1
# 41.36      1
# 41.13      1
# 40.30      1
# 35.88      1
# Name: count, Length: 862, dtype: int64
#
#
# housing_median_age
# 52    1273
# 36     862
# 35     824
# 16     771
# 17     698
# 34     689
# 26     619
# 33     615
# 18     570
# 25     566
# 32     565
# 37     537
# 15     512
# 19     502
# 27     488
# 24     478
# 30     476
# 28     471
# 20     465
# 29     461
# 31     458
# 23     448
# 21     446
# 14     412
# 22     399
# 38     394
# 39     369
# 42     368
# 44     356
# 43     353
# 40     304
# 13     302
# 41     296
# 45     294
# 10     264
# 11     254
# 46     245
# 5      244
# 12     238
# ...

# %%
df.nunique().to_frame('No. of unique values')
# Out:
#                     No. of unique values
# longitude                            844
# latitude                             862
# housing_median_age                    52
# total_rooms                         5926
# total_bedrooms                      1924
# population                          3888
# households                          1815
# median_income                      12928
# ocean_proximity                        5
# median_house_value                  3842

# %%
df['total_rooms'].nunique()
# Out:
# 5926

# %%
df.shape[0]
# Out:
# 20640

# %%
df['total_rooms'].duplicated().sum()
# Out:
# 14714

# %%
for i in df.columns:
    print(df[i].duplicated().sum())
    print('\n')
# Out:
# 19796
#
#
# 19778
#
#
# 20588
#
#
# 14714
#
#
# 18716
#
#
# 16752
#
#
# 18825
#
#
# 7712
#
#
# 20635
#
#
# 16798

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        419.266592   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# From above statistical analysis,
#
# -Here we observe negative value in longitude column.
#
# -The Mean value is greater than Median in latitude,total_rooms,total_bedrooms,population,households,median_income which means the data is skewed to right.
#
# -We observe the huge difference in between 75% and Max values that means outlier are presents.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Univariate Analysis

# %%
sns.histplot(x='housing_median_age', data=df, kde=True)
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
sns.histplot(x='total_rooms', data=df, kde=True)
# Out:
# <Axes: xlabel='total_rooms', ylabel='Count'>

# %% [markdown]
# Here we observe that, the total_room has a positive skewness.

# %%
sns.kdeplot(x='total_bedrooms', data=df)
# Out:
# <Axes: xlabel='total_bedrooms', ylabel='Density'>

# %% [markdown]
# We observed that the total_bedrooms column value has positivie skewness.

# %%
sns.histplot(x='population', data=df, kde=True)
# Out:
# <Axes: xlabel='population', ylabel='Count'>

# %%
sns.histplot(x='households', data=df, kde=True)
# Out:
# <Axes: xlabel='households', ylabel='Count'>

# %%
sns.histplot(x='median_income', data=df, kde=True)
# Out:
# <Axes: xlabel='median_income', ylabel='Count'>

# %% [markdown]
# From univariate analysis, We observe that most of the columns have positive skewness.

# %% [markdown]
# Bivatiate Analysis

# %%
sns.scatterplot(x='total_bedrooms', y='total_rooms', data=df, hue='median_house_value')
# Out:
# <Axes: xlabel='total_bedrooms', ylabel='total_rooms'>

# %% [markdown]
# Here we see that both columns has a strong linear relationship.

# %%
sns.scatterplot(x='housing_median_age', y='median_house_value', data=df)
# Out:
# <Axes: xlabel='housing_median_age', ylabel='median_house_value'>

# %%
sns.scatterplot(x='total_rooms', y='median_house_value', data=df)
# Out:
# <Axes: xlabel='total_rooms', ylabel='median_house_value'>

# %%
sns.scatterplot(x='total_bedrooms', y='median_house_value', data=df)
# Out:
# <Axes: xlabel='total_bedrooms', ylabel='median_house_value'>

# %%
sns.scatterplot(x='population', y='median_house_value', data=df)
# Out:
# <Axes: xlabel='population', ylabel='median_house_value'>

# %%
sns.scatterplot(x='households', y='median_house_value', data=df)
# Out:
# <Axes: xlabel='households', ylabel='median_house_value'>

# %%
sns.scatterplot(x='median_income', y='median_house_value', data=df)
# Out:
# <Axes: xlabel='median_income', ylabel='median_house_value'>

# %% [markdown]
# # Check Outliers

# %%
from sklearn.preprocessing import OrdinalEncoder

# Instantiate the OrdinalEncoder
OE = OrdinalEncoder()

# Extract the categorical column
categorical_column = df[['ocean_proximity']]

# Fit and transform the categorical column, and create a new encoded column
df['ocean_proximity_e'] = OE.fit_transform(categorical_column)

# Drop the original categorical column
df.drop('ocean_proximity', axis=1, inplace=True)

# Display the first few rows of the updated DataFrame
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value  \
# 0         322         126         8.3252              452600
# 1        2401        1138         8.3014              358500
# 2         496         177         7.2574              352100
# 3         558         219         5.6431              341300
# 4         565         259         3.8462              342200
#
#    ocean_proximity_e
# 0                3.0
# 1                3.0
# 2                3.0
# 3                3.0
# 4                3.0

# %%
df['ocean_proximity_e'].value_counts()
# Out:
# ocean_proximity_e
# 0.0    9136
# 1.0    6551
# 4.0    2658
# 3.0    2290
# 2.0       5
# Name: count, dtype: int64

# %% [markdown]
# # drop unnecessary column

# %%
df = df.drop(['longitude', 'latitude'], axis=1)

# %%
plt.figure(figsize=(15,8))
plot = 1

for col in df.columns:
    if plot < 8:
        ax = plt.subplot(3,3,plot)
        sns.boxplot(df[col])
        plt.xlabel(col, fontsize=15)
    plot+=1
plt.tight_layout()

# %% [markdown]
# We observe from above boxplot shows that in total_rooms,total_bedrooms,populations,housholds,and median_incom columns have outliers.So now we treat the outliers by Z-score.

# %%
from scipy.stats import zscore

abs_z_scores = df.apply(zscore).abs()
filtered_df = df[(abs_z_scores < 2.0).all(axis=1)]
df = filtered_df
df.describe()
# Out:
#        housing_median_age   total_rooms  total_bedrooms    population  \
# count        11505.000000  11505.000000    11505.000000  11505.000000
# mean            30.690743   1862.490482      393.142772   1082.871534
# std             11.635725    818.820412      164.813393    470.301092
# min              6.000000     78.000000       28.000000     54.000000
# 25%             21.000000   1273.000000      273.000000    738.000000
# 50%             32.000000   1775.000000      380.000000   1047.000000
# 75%             39.000000   2399.000000      508.000000   1409.000000
# max             52.000000   4007.000000      827.000000   2266.000000
#
#          households  median_income  median_house_value  ocean_proximity_e
# count  11505.000000   11505.000000        11505.000000       11505.000000
# mean     366.823207       3.260246       157226.848935           0.756975
# std      154.850365       1.164236        68479.480083           0.929191
# ...

# %%
plt.figure(figsize=(15,8))
plot = 1

for col in df.columns:
    if plot < 8:
        ax = plt.subplot(3,3,plot)
        sns.distplot(df[col])
        plt.xlabel(col, fontsize=15)
    plot+=1
plt.tight_layout()

# %% [markdown]
# Here we observe that, the data is almost normalized distributed.

# %%
plt.figure(figsize=(15,8))
plot = 1

for col in df.columns:
    if plot < 8:
        ax = plt.subplot(3,3,plot)
        sns.boxplot(df[col])
        plt.xlabel(col, fontsize=15)
    plot+=1
plt.tight_layout()

# %% [markdown]
# Here we observe that, there is no outlier presents in dataset which is removed by standard deviation 2.0

# %% [markdown]
# # Check Skewness

# %%
df.skew()
# Out:
# housing_median_age   -0.026660
# total_rooms           0.330406
# total_bedrooms        0.255309
# population            0.243178
# households            0.229854
# median_income         0.251156
# median_house_value    0.416569
# ocean_proximity_e     1.346253
# dtype: float64

# %% [markdown]
# Here there is no skewness.So no need to apply any transformation method

# %% [markdown]
# # Check Correlation

# %%
df_corr=df.corr().abs()

plt.figure(figsize=(20,13))
sns.heatmap(df_corr, annot=True, annot_kws={'size':10}, linecolor='white', linewidths=0.7)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Here we observe that,
#
# -Total_rooms is highly correlated with total_bedrooms and households.
#
# -population is highly correlated with housholds.

# %%
df_corr['median_house_value'].sort_values(ascending = False)
# Out:
# median_house_value    1.000000
# median_income         0.601415
# total_rooms           0.158725
# households            0.136599
# ocean_proximity_e     0.136209
# housing_median_age    0.109846
# total_bedrooms        0.091949
# population            0.034771
# Name: median_house_value, dtype: float64

# %% [markdown]
# Here we observe that no independent variable is not highly correlated with target variable.

# %%
X = df.drop('median_house_value', axis=1)
y = df['median_house_value']

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x = pd.DataFrame(sc.fit_transform(X), columns=X.columns)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['Features'] = x.columns
vif['VIF value'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]

# %%
vif
# Out:
#              Features  VIF value
# 0  housing_median_age   1.119811
# 1         total_rooms   7.703739
# 2      total_bedrooms  13.734479
# 3          population   3.644618
# 4          households  15.005875
# 5       median_income   1.605010
# 6   ocean_proximity_e   1.103754

# %% [markdown]
# By checking the VIF values we can find the features causing multicoliniearity problem.Here we can find the features total_bedrooms and households have VIF value is greater than 10 which means they have highly correlated with other independent features.So we will drop one of them first.

# %%
x.drop('households', axis=1, inplace=True)

# %%
vif = pd.DataFrame()
vif['Features'] = x.columns
vif['VIF value'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]

# %%
vif
# Out:
#              Features  VIF value
# 0  housing_median_age   1.100335
# 1         total_rooms   7.382200
# 2      total_bedrooms   7.627854
# 3          population   2.766210
# 4       median_income   1.603183
# 5   ocean_proximity_e   1.103495

# %% [markdown]
# By checking the VIF values we can find the features causing multicoliniearity problem.Here we can find the features total_bedrooms and total_rooms have VIF value is greater than 5 which means they have highly correlated with other independent features.So we will drop one of them first.

# %%
x.drop('total_bedrooms', axis=1, inplace=True)

# %%
vif = pd.DataFrame()
vif['Features'] = x.columns
vif['VIF value'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]

vif
# Out:
#              Features  VIF value
# 0  housing_median_age   1.099463
# 1         total_rooms   2.642237
# 2          population   2.396665
# 3       median_income   1.192493
# 4   ocean_proximity_e   1.099953

# %% [markdown]
# So, we have solve multicolinearity.

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,ExtraTreesRegressor
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.model_selection import cross_val_score,KFold

# %%
# LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
lr_pred = lr.predict(x_test)
print('R2_score : ', r2_score(y_test,lr_pred))
print('Mean_Squared_Error : ', mean_squared_error(y_test,lr_pred))
print('Mean_Absolute_Error : ', mean_absolute_error(y_test,lr_pred))
# Out:
# R2_score :  0.4081459396672149
# Mean_Squared_Error :  2813368426.913106
# Mean_Absolute_Error :  41589.13801149794

# %%
# Lasso
l = Lasso(alpha=1.0)
l.fit(x_train,y_train)
l_pred = l.predict(x_test)
print('R2_score : ', r2_score(y_test,l_pred))
print('Mean_Squared_Error : ', mean_squared_error(y_test,l_pred))
print('Mean_Absolute_Error : ', mean_absolute_error(y_test,l_pred))
# Out:
# R2_score :  0.4081456059446751
# Mean_Squared_Error :  2813370013.257645
# Mean_Absolute_Error :  41589.2083149804

# %%
# RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(x_train,y_train)
r_pred = rfr.predict(x_test)
print('R2_score : ', r2_score(y_test,r_pred))
print('Mean_Squared_Error : ', mean_squared_error(y_test,r_pred))
print('Mean_Absolute_Error : ', mean_absolute_error(y_test,r_pred))
# Out:
# R2_score :  0.5962886448904239
# Mean_Squared_Error :  1919035208.4650054
# Mean_Absolute_Error :  32879.390060843114

# %%
# GradientBoostingRegressor
gbr = GradientBoostingRegressor()
gbr.fit(x_train,y_train)
g_pred = gbr.predict(x_test)
print('R2_score : ', r2_score(y_test,g_pred))
print('Mean_Squared_Error : ', mean_squared_error(y_test,g_pred))
print('Mean_Absolute_Error : ', mean_absolute_error(y_test,g_pred))
# Out:
# R2_score :  0.600153239547414
# Mean_Squared_Error :  1900664922.0726483
# Mean_Absolute_Error :  33043.39001279586

# %%
# ExtraTreesRegressor
etr = ExtraTreesRegressor()
etr.fit(x_train,y_train)
e_pred = etr.predict(x_test)
print('R2_score : ', r2_score(y_test,e_pred))
print('Mean_Squared_Error : ', mean_squared_error(y_test,e_pred))
print('Mean_Absolute_Error : ', mean_absolute_error(y_test,e_pred))
# Out:
# R2_score :  0.5856034788330777
# Mean_Squared_Error :  1969826967.5097249
# Mean_Absolute_Error :  33458.50787049109

# %%
# Ridge
r = Ridge()
r.fit(x_train,y_train)
rr_pred = r.predict(x_test)
print('R2_score : ', r2_score(y_test,rr_pred))
print('Mean_Squared_Error : ', mean_squared_error(y_test,rr_pred))
print('Mean_Absolute_Error : ', mean_absolute_error(y_test,rr_pred))
# Out:
# R2_score :  0.408145837033807
# Mean_Squared_Error :  2813368914.779302
# Mean_Absolute_Error :  41589.3479014997

# %% [markdown]
# # Cross Validation

# %%
# LinearRegression
k_folds = KFold(n_splits=5)
score = cross_val_score(lr,x,y,cv=k_folds)
print("Cross Validation Score : {}".format(score))
print("Average Cross Validation Score : {}".format(score.mean()))
print("\n------------------")
r2_score(y_test,lr_pred) - score.mean()
# Out:
# Cross Validation Score : [0.25273276 0.15218265 0.33030207 0.28000589 0.44427716]
# Average Cross Validation Score : 0.2919001066523016
#
# ------------------
# 0.11624583301491331

# %%
# Lasso
k_folds = KFold(n_splits=5)
score = cross_val_score(l,x,y,cv=k_folds)
print("Cross Validation Score : {}".format(score))
print("Average Cross Validation Score : {}".format(score.mean()))
print("\n------------------")
r2_score(y_test,l_pred) - score.mean()
# Out:
# Cross Validation Score : [0.25274934 0.1521728  0.33030905 0.28001858 0.44427365]
# Average Cross Validation Score : 0.29190468215109056
#
# ------------------
# 0.11624092379358453

# %%
# RandomForestRegressor
k_folds = KFold(n_splits=5)
score = cross_val_score(rfr,x,y,cv=k_folds)
print("Cross Validation Score : {}".format(score))
print("Average Cross Validation Score : {}".format(score.mean()))
print("\n------------------")
r2_score(y_test,r_pred) - score.mean()
# Out:
# Cross Validation Score : [0.36132793 0.32001516 0.46395864 0.44532853 0.61027897]
# Average Cross Validation Score : 0.44018184733937743
#
# ------------------
# 0.15610679755104645

# %%
# GradientBoostingRegressor
k_folds = KFold(n_splits=5)
score = cross_val_score(gbr,x,y,cv=k_folds)
print("Cross Validation Score : {}".format(score))
print("Average Cross Validation Score : {}".format(score.mean()))
print("\n------------------")
r2_score(y_test,g_pred) - score.mean()
# Out:
# Cross Validation Score : [0.4103111  0.32135043 0.47189445 0.51661451 0.63822035]
# Average Cross Validation Score : 0.4716781665127856
#
# ------------------
# 0.12847507303462835

# %%
# ExtraTreesRegressor
k_folds = KFold(n_splits=5)
score = cross_val_score(etr,x,y,cv=k_folds)
print("Cross Validation Score : {}".format(score))
print("Average Cross Validation Score : {}".format(score.mean()))
print("\n------------------")
r2_score(y_test,e_pred) - score.mean()
# Out:
# Cross Validation Score : [0.34212451 0.30528432 0.45426428 0.43959287 0.60662337]
# Average Cross Validation Score : 0.4295778705026875
#
# ------------------
# 0.15602560833039025

# %%
# Ridge
k_folds = KFold(n_splits=5)
score = cross_val_score(r,x,y,cv=k_folds)
print("Cross Validation Score : {}".format(score))
print("Average Cross Validation Score : {}".format(score.mean()))
print("\n------------------")
r2_score(y_test,rr_pred) - score.mean()
# Out:
# Cross Validation Score : [0.25272061 0.15219265 0.33031559 0.28001915 0.44426527]
# Average Cross Validation Score : 0.29190265523169695
#
# ------------------
# 0.11624318180211007

# %% [markdown]
# # Here Three models like Linear Regression, Lasso , Ridge regression are our best model as the difference between r2_score and cross validation score is least.We can use one of them.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# Lasso
parameters = {
    'alpha': np.logspace(-4, 4, 50)
 }

# %%
rcv = RandomizedSearchCV(Lasso(),parameters,cv=5, random_state=42)

# %%
rcv.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=Lasso(),
#                    param_distributions={'alpha': array([1.00000000e-04, 1.45634848e-04, 2.12095089e-04, 3.08884360e-04,
#        4.49843267e-04, 6.55128557e-04, 9.54095476e-04, 1.38949549e-03,
#        2.02358965e-03, 2.94705170e-03, 4.29193426e-03, 6.25055193e-03,
#        9.10298178e-03, 1.32571137e-02, 1.93069773e-02, 2.81176870e-02,
#        4.09491506e-02, 5.96362332e-02, 8....
#        8.28642773e-01, 1.20679264e+00, 1.75751062e+00, 2.55954792e+00,
#        3.72759372e+00, 5.42867544e+00, 7.90604321e+00, 1.15139540e+01,
#        1.67683294e+01, 2.44205309e+01, 3.55648031e+01, 5.17947468e+01,
#        7.54312006e+01, 1.09854114e+02, 1.59985872e+02, 2.32995181e+02,
#        3.39322177e+02, 4.94171336e+02, 7.19685673e+02, 1.04811313e+03,
#        1.52641797e+03, 2.22299648e+03, 3.23745754e+03, 4.71486636e+03,
#        6.86648845e+03, 1.00000000e+04])},
#                    random_state=42)

# %%
rcv.best_params_
# Out:
# {'alpha': 232.99518105153672}

# %%
model = Lasso(alpha=232.99518105153672)
model.fit(x_train,y_train)
m_pred = model.predict(x_test)
print('R2 Score : ', r2_score(y_test,m_pred)*100)
# Out:
# R2 Score :  40.77585138617161

# %% [markdown]
# # Save the Model

# %%
import joblib

joblib.dump(model,'House_price_prediction.pkl')
# Out:
# ['House_price_prediction.pkl']

# %%
g = joblib.load('House_price_prediction.pkl')

pred = g.predict(x_test)
ac= np.array(y_test)
pd.DataFrame({
    'Actual':ac,
    'Prediction':pred
})
# Out:
#       Actual     Prediction
# 0     218200  209946.537944
# 1      95900  167680.566953
# 2     167500  126063.603688
# 3      43500  118086.839870
# 4     216900  158584.484706
# ...      ...            ...
# 2296  134200  140818.248116
# 2297  219000  156695.020185
# 2298   26600  123889.826194
# 2299  243600  231575.878751
# 2300   75600  146530.229999
#
# [2301 rows x 2 columns]
