# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\akash\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\akash\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('GOOG.csv')

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2004-08-19    2.490664    2.591785    2.390042    2.499133    2.499133
# 1     2004-08-20    2.515820    2.716817    2.503118    2.697639    2.697639
# 2     2004-08-23    2.758411    2.826406    2.716070    2.724787    2.724787
# 3     2004-08-24    2.770615    2.779581    2.579581    2.611960    2.611960
# 4     2004-08-25    2.614201    2.689918    2.587302    2.640104    2.640104
# ...          ...         ...         ...         ...         ...         ...
# 4853  2023-11-29  138.985001  139.669998  136.294998  136.399994  136.399994
# 4854  2023-11-30  136.399994  136.960007  132.789993  133.919998  133.919998
# 4855  2023-12-01  133.320007  133.500000  132.151993  133.320007  133.320007
# 4856  2023-12-04  131.294006  131.449997  129.399994  130.630005  130.630005
# 4857  2023-12-05  130.369995  133.539993  129.729996  132.389999  132.389999
#
#          Volume
# 0     897427216
# ...

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2004-08-19  2.490664  2.591785  2.390042  2.499133   2.499133  897427216
# 1  2004-08-20  2.515820  2.716817  2.503118  2.697639   2.697639  458857488
# 2  2004-08-23  2.758411  2.826406  2.716070  2.724787   2.724787  366857939
# 3  2004-08-24  2.770615  2.779581  2.579581  2.611960   2.611960  306396159
# 4  2004-08-25  2.614201  2.689918  2.587302  2.640104   2.640104  184645512

# %%
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 4853  2023-11-29  138.985001  139.669998  136.294998  136.399994  136.399994
# 4854  2023-11-30  136.399994  136.960007  132.789993  133.919998  133.919998
# 4855  2023-12-01  133.320007  133.500000  132.151993  133.320007  133.320007
# 4856  2023-12-04  131.294006  131.449997  129.399994  130.630005  130.630005
# 4857  2023-12-05  130.369995  133.539993  129.729996  132.389999  132.389999
#
#         Volume
# 4853  21014700
# 4854  29913500
# 4855  24258400
# 4856  24117100
# 4857  19216500

# %%
df.shape
# Out:
# (4858, 7)

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
print('Min Date : ',df.Date.min())
print('Max Date : ', df.Date.max())
# Out:
# Min Date :  2004-08-19
# Max Date :  2023-12-05

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# As we can see there are no null values is present in dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4858 entries, 0 to 4857
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4858 non-null   object
#  1   Open       4858 non-null   float64
#  2   High       4858 non-null   float64
#  3   Low        4858 non-null   float64
#  4   Close      4858 non-null   float64
#  5   Adj Close  4858 non-null   float64
#  6   Volume     4858 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 265.8+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4858 entries, 0 to 4857
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4858 non-null   datetime64[ns]
#  1   Open       4858 non-null   float64
#  2   High       4858 non-null   float64
#  3   Low        4858 non-null   float64
#  4   Close      4858 non-null   float64
#  5   Adj Close  4858 non-null   float64
#  6   Volume     4858 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 265.8 KB

# %%
df.set_index('Date', inplace=True)

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2004-08-19    2.490664    2.591785    2.390042    2.499133    2.499133
# 2004-08-20    2.515820    2.716817    2.503118    2.697639    2.697639
# 2004-08-23    2.758411    2.826406    2.716070    2.724787    2.724787
# 2004-08-24    2.770615    2.779581    2.579581    2.611960    2.611960
# 2004-08-25    2.614201    2.689918    2.587302    2.640104    2.640104
# ...                ...         ...         ...         ...         ...
# 2023-11-29  138.985001  139.669998  136.294998  136.399994  136.399994
# 2023-11-30  136.399994  136.960007  132.789993  133.919998  133.919998
# 2023-12-01  133.320007  133.500000  132.151993  133.320007  133.320007
# 2023-12-04  131.294006  131.449997  129.399994  130.630005  130.630005
# 2023-12-05  130.369995  133.539993  129.729996  132.389999  132.389999
#
#                Volume
# Date
# 2004-08-19  897427216
# 2004-08-20  458857488
# 2004-08-23  366857939
# ...

# %%
df.nunique().to_frame('no. of unique values')
# Out:
#            no. of unique values
# Open                       4713
# High                       4712
# Low                        4743
# Close                      4765
# Adj Close                  4765
# Volume                     4747

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicate values.

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# Open
# 14.719826     4
# 49.000000     4
# 13.113846     3
# 11.457056     3
# 67.500000     3
#              ..
# 14.939005     1
# 15.386826     1
# 15.239379     1
# 15.227673     1
# 130.369995    1
# Name: count, Length: 4713, dtype: int64
#
#
# High
# 12.627668     3
# 60.000000     3
# 12.951455     3
# 13.121318     3
# 10.112097     3
#              ..
# 14.432155     1
# 14.386077     1
# 14.368892     1
# 14.398531     1
# 131.449997    1
# Name: count, Length: 4712, dtype: int64
#
#
# Low
# 14.396040     3
# 11.917829     3
# 12.702388     3
# 12.926548     3
# 128.039993    2
#              ..
# 14.489191     1
# 14.460299     1
# 14.271756     1
# 14.314097     1
# 129.729996    1
# Name: count, Length: 4743, dtype: int64
#
#
# Close
# 14.445853     3
# 15.354946     3
# 14.520573     3
# 114.699997    2
# 14.588818     2
#              ..
# 14.488942     1
# 14.330287     1
# 14.439378     1
# 14.617460     1
# 132.389999    1
# Name: count, Length: 4765, dtype: int64
# ...

# %% [markdown]
# So here we drop the Adj Close column  since they contain same values.

# %%
df.drop('Adj Close',axis=1,inplace=True)

# %%
df
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2004-08-19    2.490664    2.591785    2.390042    2.499133  897427216
# 2004-08-20    2.515820    2.716817    2.503118    2.697639  458857488
# 2004-08-23    2.758411    2.826406    2.716070    2.724787  366857939
# 2004-08-24    2.770615    2.779581    2.579581    2.611960  306396159
# 2004-08-25    2.614201    2.689918    2.587302    2.640104  184645512
# ...                ...         ...         ...         ...        ...
# 2023-11-29  138.985001  139.669998  136.294998  136.399994   21014700
# 2023-11-30  136.399994  136.960007  132.789993  133.919998   29913500
# 2023-12-01  133.320007  133.500000  132.151993  133.320007   24258400
# 2023-12-04  131.294006  131.449997  129.399994  130.630005   24117100
# 2023-12-05  130.369995  133.539993  129.729996  132.389999   19216500
#
# [4858 rows x 5 columns]

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  4858.000000  4858.000000  4858.000000  4858.000000  4.858000e+03
# mean     41.477174    41.917059    41.055491    41.494404  1.189152e+08
# std      38.590695    39.031758    38.193016    38.618107  1.512424e+08
# min       2.470490     2.534002     2.390042     2.490913  1.584340e+05
# 25%      12.846597    12.954195    12.712414    12.834642  2.854912e+07
# 50%      26.499958    26.728268    26.289323    26.537501  6.168836e+07
# 75%      57.367250    58.028500    56.962251    57.611249  1.467329e+08
# max     151.863495   152.100006   149.887497   150.709000  1.650833e+09

# %% [markdown]
# This is given statistical information of numerical columns.The summary of the dataset looks perfect since there is no negative value present.
#
# From above description we obseve that,
#
# -The count of all columns are same i.e there are no missing values are present.
#
# -The Mean value is greater than Median value in open,high,low,close columns in dataset which means the data is skewed to right.
#
# -The Median value is greater than Mean value in volume column which means the data is left skewed.
#
# -In 75% and Max values have huge difference so the outliers are present in columns.

# %% [markdown]
# # Data Visualization

# %%
sns.lmplot(x='Open', y='Close', data=df)

# %% [markdown]
# Open has strong positive correlation with Close and has strong linear relationship between both.

# %%
sns.regplot(x='Low', y='Close', data=df)
# Out:
# <Axes: xlabel='Low', ylabel='Close'>

# %% [markdown]
# Low has strong positive correlation with Close and has strong linear relationship between both.

# %%
sns.scatterplot(x='Volume', y='Close',data=df)
# Out:
# <Axes: xlabel='Volume', ylabel='Close'>

# %% [markdown]
# Volume has negative correlation with Close.

# %%
sns.lmplot(x='Volume', y='Close', data=df)

# %%
plt.figure(figsize=(20,15))
plotnumber = 1

for col in df.columns:
    if plotnumber <= 10:
        ax= plt.subplot(4,4,plotnumber)
        sns.scatterplot(x='Close', y=col, data=df, color='y')
    plotnumber+=1
plt.tight_layout()

# %%
sns.pairplot(df)

# %% [markdown]
# The pairplot gives the pairwise relationship between the features. On the diagonal we can notice the distribution plot.
#
# The features Low, High, Open has strong linear relation with each other.

# %%
plt.figure(figsize=(15,8))
plt.plot(df.Close, label='Closing Price')
plt.ylabel('Stock Price')
plt.xlabel('Time')
plt.title('Tesla Stock Price')
plt.show()

# %% [markdown]
# # Check Ouliers

# %%
plt.figure(figsize=(15,8))
p = 1

for i in df[['Open','High','Low','Volume']]:
    if p <= 8:
        ax=plt.subplot(3,3,p)
        sns.boxplot(df[i])
    p+=1
plt.show()

# %% [markdown]
# Here we observe that the outliers are present in all columns.So we have to remove it using z-score

# %% [markdown]
# # applying a log transformation can reduce skewness and make extreme values less prominent.

# %%
df=np.log(df)

# %%
from scipy.stats import zscore
f = df[['Open','High','Low','Volume']]
z_score = np.abs(zscore(f))

p =(z_score < 3).all(axis=1)
df1= df[p]
df1.describe()
# Out:
#               Open         High          Low        Close       Volume
# count  4849.000000  4849.000000  4849.000000  4849.000000  4849.000000
# mean      3.302326     3.312866     3.291525     3.302400    18.046619
# std       0.939641     0.938847     0.940935     0.939981     1.004784
# min       0.904417     0.929800     0.871311     0.912649    15.752236
# 25%       2.553874     2.562169     2.542770     2.552517    17.169057
# 50%       3.277116     3.285653     3.269011     3.278465    17.937964
# 75%       4.050462     4.062593     4.043174     4.054251    18.803379
# max       5.022982     5.024538     5.009885     5.015351    21.106030

# %%
plt.figure(figsize=(15,8))
p = 1

for i in df1[['Open','High','Low','Volume']]:
    if p <= 8:
        ax=plt.subplot(3,3,p)
        sns.boxplot(df1[i])
    p+=1
plt.show()

# %%
# np.where(z_score>2.3)

# %%
# z_score.iloc[4857,2]

# %%
print('Old Dtaframe size : ',df.shape[0])
print('New Dtaframe size : ',df1.shape[0])
# Out:
# Old Dtaframe size :  4858
# New Dtaframe size :  4849

# %%
print('Data Loss Percentage : ',((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data Loss Percentage :  0.18526142445450802

# %%
plt.figure(figsize=(15,8), facecolor='yellow')
p = 1

for i in df1[['Open','High','Low','Volume']]:
    if p <= 8:
        ax=plt.subplot(3,3,p)
        sns.distplot(df1[i])
    p+=1
plt.show()

# %% [markdown]
#  Here the data is almost normally distributed

# %% [markdown]
# # Checking Skewness

# %%
df1.skew()
# Out:
# Open      0.096885
# High      0.104233
# Low       0.092230
# Close     0.098162
# Volume    0.455228
# dtype: float64

# %% [markdown]
# # check correlation

# %%
df1.corr()
# Out:
#             Open      High       Low     Close    Volume
# Open    1.000000  0.999942  0.999932  0.999873 -0.847551
# High    0.999942  1.000000  0.999907  0.999936 -0.845913
# Low     0.999932  0.999907  1.000000  0.999940 -0.849746
# Close   0.999873  0.999936  0.999940  1.000000 -0.847975
# Volume -0.847551 -0.845913 -0.849746 -0.847975  1.000000

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df1.corr(), annot=True, annot_kws={'size':10}, linecolor='white', linewidths=1)
# Out:
# <Axes: >

# %%
df1.corr().Close.sort_values()
# Out:
# Volume   -0.847975
# Open      0.999873
# High      0.999936
# Low       0.999940
# Close     1.000000
# Name: Close, dtype: float64

# %% [markdown]
# # Separating the features and target variables

# %%
X = df1.drop('Close', axis=1)
y = df1['Close']

# %% [markdown]
# # Feature Scaling using StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x = pd.DataFrame(sc.fit_transform(X), columns=X.columns)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['Features'] = x.columns
vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range(x.shape[1])]

vif
# Out:
#   Features    VIF values
# 0     Open  12592.910396
# 1     High  11129.291415
# 2      Low  10226.693709
# 3   Volume      4.953064

# %% [markdown]
# # Find the best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.ensemble import GradientBoostingRegressor,ExtraTreesRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
maxAccu = 0
maxRS = 0

for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=i)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Maximum accuracy is ', maxAccu, 'on random state ', maxRS)
# Out:
# Maximum accuracy is  0.9999600088310567 on random state  143

# %% [markdown]
# # Model

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=maxRS)

# %%
# LinearRegression
LR = LinearRegression()
LR.fit(x_train,y_train)
LR_pred = LR.predict(x_test)
print(LR)
print('\n------------------------------------------')
print('Training Accuracy : {}'.format(r2_score(LR.predict(x_train),y_train)*100))
print('\n--------------------------------------------')
print('Testing Accuracy : {}'.format(r2_score(y_test,LR_pred)*100))
print('\n')
print('Mean Squared Error : ',mean_squared_error(y_test,LR_pred))
print('Mean Absolute Error : ',mean_absolute_error(y_test,LR_pred))
print('Root Mean Squared Error : ',np.sqrt(mean_squared_error(y_test,LR_pred)))
# Out:
# LinearRegression()
#
# ------------------------------------------
# Training Accuracy : 99.9947286466708
#
# --------------------------------------------
# Testing Accuracy : 99.99600088310568
#
#
# Mean Squared Error :  3.7562703863941365e-05
# Mean Absolute Error :  0.004419035881779035
# Root Mean Squared Error :  0.006128841967610306

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=LR_pred, y=y_test, color='r')
plt.plot(LR_pred,LR_pred,color='b')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Linear Regression')
plt.show()

# %%
# GradientBoostingRegressor
GBR = GradientBoostingRegressor()
GBR.fit(x_train,y_train)
GBR_pred = GBR.predict(x_test)
print(GBR)
print('\n------------------------------------------')
print('Training Accuracy : {}'.format(r2_score(GBR.predict(x_train),y_train)*100))
print('\n--------------------------------------------')
print('Testing Accuracy : {}'.format(r2_score(y_test,GBR_pred)*100))
print('\n')
print('Mean Squared Error : ',mean_squared_error(y_test,GBR_pred))
print('Mean Absolute Error : ',mean_absolute_error(y_test,GBR_pred))
print('Root Mean Squared Error : ',np.sqrt(mean_squared_error(y_test,GBR_pred)))
# Out:
# GradientBoostingRegressor()
#
# ------------------------------------------
# Training Accuracy : 99.9905785855191
#
# --------------------------------------------
# Testing Accuracy : 99.98614584707173
#
#
# Mean Squared Error :  0.0001301285902566335
# Mean Absolute Error :  0.008359141593908569
# Root Mean Squared Error :  0.011407391912993675

# %%
# ExtraTreesRegressor
ETR = ExtraTreesRegressor()
ETR.fit(x_train,y_train)
ETR_pred = ETR.predict(x_test)
print(ETR)
print('\n------------------------------------------')
print('Training Accuracy : {}'.format(r2_score(ETR.predict(x_train),y_train)*100))
print('\n--------------------------------------------')
print('Testing Accuracy : {}'.format(r2_score(y_test,ETR_pred)*100))
print('\n')
print('Mean Squared Error : ',mean_squared_error(y_test,ETR_pred))
print('Mean Absolute Error : ',mean_absolute_error(y_test,ETR_pred))
print('Root Mean Squared Error : ',np.sqrt(mean_squared_error(y_test,ETR_pred)))
# Out:
# ExtraTreesRegressor()
#
# ------------------------------------------
# Training Accuracy : 100.0
#
# --------------------------------------------
# Testing Accuracy : 99.99309582037507
#
#
# Mean Squared Error :  6.484923084946699e-05
# Mean Absolute Error :  0.005736725383807972
# Root Mean Squared Error :  0.00805290201414788

# %%
# Ridge
R = Ridge()
R.fit(x_train,y_train)
R_pred = R.predict(x_test)
print(R)
print('\n------------------------------------------')
print('Training Accuracy : {}'.format(r2_score(R.predict(x_train),y_train)*100))
print('\n--------------------------------------------')
print('Testing Accuracy : {}'.format(r2_score(y_test,R_pred)*100))
print('\n')
print('Mean Squared Error : ',mean_squared_error(y_test,R_pred))
print('Mean Absolute Error : ',mean_absolute_error(y_test,R_pred))
print('Root Mean Squared Error : ',np.sqrt(mean_squared_error(y_test,R_pred)))
# Out:
# Ridge()
#
# ------------------------------------------
# Training Accuracy : 99.98925210671393
#
# --------------------------------------------
# Testing Accuracy : 99.9922177700837
#
#
# Mean Squared Error :  7.30965374284714e-05
# Mean Absolute Error :  0.0063111510173834
# Root Mean Squared Error :  0.008549651304496073

# %% [markdown]
# # Cross Validation check

# %%
from sklearn.model_selection import cross_val_score,KFold

# %%
# LinearRegression
k = KFold(n_splits=5)
score = cross_val_score(LR,x,y,cv=k, scoring='r2')
print("Cross Validation Score : {}".format(score))
print("Average Cross Validation Score : {}".format(score.mean()))
print("\n------------------")
(r2_score(y_test,LR_pred) - score.mean())*100
# Out:
# Cross Validation Score : [0.99975307 0.99847618 0.9995981  0.99937423 0.99912722]
# Average Cross Validation Score : 0.9992657611385235
#
# ------------------
# 0.06942476925332342

# %%
# GradientBoostingRegressor
k = KFold(n_splits=5)
score = cross_val_score(GBR,x,y,cv=k,scoring='r2')
print("Cross Validation Score : {}".format(score))
print("Average Cross Validation Score : {}".format(score.mean()))
print("\n------------------")
(r2_score(y_test,GBR_pred) - score.mean())*100
# Out:
# Cross Validation Score : [ 0.76380446  0.99505232  0.6812587   0.94975086 -2.04167491]
# Average Cross Validation Score : 0.26963828597974365
#
# ------------------
# 73.02231724909736

# %%
# ExtraTreesRegressor
k = KFold(n_splits=5)
score = cross_val_score(ETR,x,y,cv=k,scoring='r2')
print("Cross Validation Score : {}".format(score))
print("Average Cross Validation Score : {}".format(score.mean()))
print("\n------------------")
(r2_score(y_test,ETR_pred) - score.mean())*100
# Out:
# Cross Validation Score : [ 0.76417468  0.99763139  0.99215971  0.99647271 -1.98521555]
# Average Cross Validation Score : 0.3530445861789425
#
# ------------------
# 64.68863720248082

# %%
# Ridge
k = KFold(n_splits=5)
score = cross_val_score(R,x,y,cv=k,scoring='r2')
print("Cross Validation Score : {}".format(score))
print("Average Cross Validation Score : {}".format(score.mean()))
print("\n------------------")
(r2_score(y_test,R_pred) - score.mean())*100
# Out:
# Cross Validation Score : [0.99940575 0.99729201 0.99921035 0.99872465 0.99836704]
# Average Cross Validation Score : 0.9985999602041143
#
# ------------------
# 0.13222174967226774

# %% [markdown]
# # From the difference of both R2 score and cross validation score we can conclude that Linear Regression is our best fit and best performing model

# %%
from sklearn.model_selection import GridSearchCV

# %%
params ={
    'fit_intercept' : [True,False],
    'positive' : [True,False],
    'n_jobs' : [10,30,25,None]
}

# %%
lrcv = GridSearchCV(LinearRegression(),params,cv=5)

# %%
lrcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'fit_intercept': [True, False],
#                          'n_jobs': [10, 30, 25, None],
#                          'positive': [True, False]})

# %%
lrcv.best_params_
# Out:
# {'fit_intercept': True, 'n_jobs': 10, 'positive': False}

# %%
model = LinearRegression(fit_intercept= True, n_jobs= 10, positive= False)
model.fit(x_train,y_train)
m_pred = model.predict(x_test)
print('\n------------------------------------------')
print('Testing Accuracy : {}'.format(r2_score(y_test,m_pred)*100))
print('\n')
print('Mean Squared Error : ',mean_squared_error(y_test,m_pred))
print('Mean Absolute Error : ',mean_absolute_error(y_test,m_pred))
print('Root Mean Squared Error : ',np.sqrt(mean_squared_error(y_test,m_pred)))
# Out:
# ------------------------------------------
# Testing Accuracy : 99.99600088310568
#
#
# Mean Squared Error :  3.7562703863941365e-05
# Mean Absolute Error :  0.004419035881779035
# Root Mean Squared Error :  0.006128841967610306

# %%
import pickle
filename = 'Google_Stock_Prediction.pkl'
pickle.dump(model, open(filename, 'wb'))

# %%
import pickle
load_model = pickle.load(open('Google_Stock_Prediction.pkl','rb'))

result = load_model.score(x_test,y_test)
print(result*100)
# Out:
# 99.99600088310568

# %%
conclusion = pd.DataFrame([load_model.predict(x_test)[:],y_test[:]],index=['Predicted','Actual'])

conclusion
# Out:
#                0         1         2         3         4         5     \
# Predicted  2.501677  2.475750  4.880034  4.851735  4.114698  2.526835
# Actual     2.500682  2.474791  4.875155  4.851327  4.115902  2.527691
#
#                6         7         8         9     ...      1445      1446  \
# Predicted  3.266178  3.943862  2.741487  4.045801  ...  2.454746  4.891970
# Actual     3.260648  3.927955  2.742151  4.049870  ...  2.457086  4.891927
#
#                1447      1448      1449      1450      1451      1452  \
# Predicted  4.901472  2.638976  4.147373  3.835597  4.891207  2.500649
# Actual     4.903432  2.639735  4.145212  3.836221  4.887955  2.500151
#
#                1453      1454
# Predicted  1.621897  2.755489
# Actual     1.626577  2.754432
#
# [2 rows x 1455 columns]
